# %%
import pandas as pd
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy.stats as stats
from statistics import mean

current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
soybean = pd.read_excel('/Users/ReginaJoie/Downloads/Tillage.xlsx')

soybean
# Out:
#     SamplingYear       Tillage_C       Tillage_T Tillage_Top_C Tillage_Top_T  \
# 0           2002      No-tillage      No-tillage            NT            NT
# 1           2002     Chisel plow     Chisel plow            RT            RT
# 2           2002  Moldboard plow  Moldboard plow            CT            CT
# 3           2004      No-tillage      No-tillage            NT            NT
# 4           2004     Chisel plow     Chisel plow            RT            RT
# 5           2004  Moldboard plow  Moldboard plow            CT            CT
# 6           2006      No-tillage      No-tillage            NT            NT
# 7           2006     Chisel plow     Chisel plow            RT            RT
# 8           2006  Moldboard plow  Moldboard plow            CT            CT
# 9           2008      No-tillage      No-tillage            NT            NT
# 10          2008     Chisel plow     Chisel plow            RT            RT
# 11          2008  Moldboard plow  Moldboard plow            CT            CT
# 12          2010      No-tillage      No-tillage            NT            NT
# 13          2010     Chisel plow     Chisel plow            RT            RT
# 14          2010  Moldboard plow  Moldboard plow            CT            CT
# 15          2012      No-tillage      No-tillage            NT            NT
# 16          2012     Chisel plow     Chisel plow            RT            RT
# 17          2012  Moldboard plow  Moldboard plow            CT            CT
# 18          2002      No-tillage      No-tillage            NT            NT
# 19          2002     Chisel plow     Chisel plow            RT            RT
# 20          2002  Moldboard plow  Moldboard plow            CT            CT
# 21          2004      No-tillage      No-tillage            NT            NT
# 22          2004     Chisel plow     Chisel plow            RT            RT
# 23          2004  Moldboard plow  Moldboard plow            CT            CT
# 24          2006      No-tillage      No-tillage            NT            NT
# 25          2006     Chisel plow     Chisel plow            RT            RT
# 26          2006  Moldboard plow  Moldboard plow            CT            CT
# 27          2008      No-tillage      No-tillage            NT            NT
# 28          2008     Chisel plow     Chisel plow            RT            RT
# 29          2008  Moldboard plow  Moldboard plow            CT            CT
# 30          2010      No-tillage      No-tillage            NT            NT
# 31          2010     Chisel plow     Chisel plow            RT            RT
# 32          2010  Moldboard plow  Moldboard plow            CT            CT
# 33          2012      No-tillage      No-tillage            NT            NT
# 34          2012     Chisel plow     Chisel plow            RT            RT
# 35          2012  Moldboard plow  Moldboard plow            CT            CT
#
#    Tillage_Diff Conservation_Type  BiomassCash_C  BiomassCash_T  \
# 0            No             CC-NT            293            298
# 1            No             CC-RT            393            380
# 2            No                CC            420            403
# 3            No             CC-NT            240            253
# 4            No             CC-RT            228            233
# 5            No                CC            255            245
# 6            No             CC-NT            320            330
# 7            No             CC-RT            363            400
# 8            No                CC            388            415
# 9            No             CC-NT            310            270
# 10           No             CC-RT            390            398
# 11           No                CC            360            333
# 12           No             CC-NT            297            291
# 13           No             CC-RT            274            284
# 14           No                CC            286            290
# 15           No             CC-NT            170            166
# 16           No             CC-RT            128            124
# 17           No                CC            100             96
# 18           No             CC-NT             63             65
# 19           No             CC-RT             56             58
# 20           No                CC             68             64
# 21           No             CC-NT             60             61
# 22           No             CC-RT             61             60
# 23           No                CC             60             61
# 24           No             CC-NT             71             72
# 25           No             CC-RT             76             76
# 26           No                CC             69             68
# 27           No             CC-NT             68             66
# 28           No             CC-RT             68             68
# 29           No                CC             68             66
# 30           No             CC-NT             65             69
# 31           No             CC-RT             66             66
# 32           No                CC             64             68
# 33           No             CC-NT             75             76
# 34           No             CC-RT             69             66
# 35           No                CC             62             61
#
#                      1.BiomassCash_Comments  Yield_C  Yield_T
# 0   Soybean population (1000 plants per ha)   2370.0   2240.0
# 1   Soybean population (1000 plants per ha)   2070.0   1780.0
# 2   Soybean population (1000 plants per ha)   1980.0   1980.0
# 3   Soybean population (1000 plants per ha)      NaN      NaN
# 4   Soybean population (1000 plants per ha)      NaN      NaN
# 5   Soybean population (1000 plants per ha)      NaN      NaN
# 6   Soybean population (1000 plants per ha)   3170.0   2900.0
# 7   Soybean population (1000 plants per ha)   3370.0   2840.0
# 8   Soybean population (1000 plants per ha)   3100.0   3300.0
# 9   Soybean population (1000 plants per ha)   2840.0   3100.0
# 10  Soybean population (1000 plants per ha)   2840.0   2900.0
# 11  Soybean population (1000 plants per ha)   3040.0   3040.0
# 12  Soybean population (1000 plants per ha)   2940.0   2860.0
# 13  Soybean population (1000 plants per ha)   2790.0   2530.0
# 14  Soybean population (1000 plants per ha)   2880.0   2750.0
# 15  Soybean population (1000 plants per ha)   2650.0   2870.0
# 16  Soybean population (1000 plants per ha)   1960.0   2160.0
# 17  Soybean population (1000 plants per ha)   1820.0   1710.0
# 18     Corn population (1000 plants per ha)   9930.0   9530.0
# 19     Corn population (1000 plants per ha)   9900.0   9300.0
# 20     Corn population (1000 plants per ha)  10400.0  10200.0
# 21     Corn population (1000 plants per ha)   6670.0   6860.0
# 22     Corn population (1000 plants per ha)   7330.0   7130.0
# 23     Corn population (1000 plants per ha)   7720.0   8450.0
# 24     Corn population (1000 plants per ha)  11440.0  11400.0
# 25     Corn population (1000 plants per ha)  11860.0  11630.0
# 26     Corn population (1000 plants per ha)  11420.0  12040.0
# 27     Corn population (1000 plants per ha)   6460.0   6200.0
# 28     Corn population (1000 plants per ha)   6800.0   6730.0
# 29     Corn population (1000 plants per ha)   6800.0   6730.0
# 30     Corn population (1000 plants per ha)  13130.0  12330.0
# 31     Corn population (1000 plants per ha)  13610.0  12640.0
# 32     Corn population (1000 plants per ha)  14030.0  13970.0
# 33     Corn population (1000 plants per ha)   6130.0   6100.0
# 34     Corn population (1000 plants per ha)   6850.0   7030.0
# 35     Corn population (1000 plants per ha)   7680.0   6490.0

# %% [markdown]
# ### Dropping Corn Population and Keeping Soybean Population ###

# %%
soy = soybean.iloc[:18]

soy
# Out:
#     SamplingYear       Tillage_C       Tillage_T Tillage_Top_C Tillage_Top_T  \
# 0           2002      No-tillage      No-tillage            NT            NT
# 1           2002     Chisel plow     Chisel plow            RT            RT
# 2           2002  Moldboard plow  Moldboard plow            CT            CT
# 3           2004      No-tillage      No-tillage            NT            NT
# 4           2004     Chisel plow     Chisel plow            RT            RT
# 5           2004  Moldboard plow  Moldboard plow            CT            CT
# 6           2006      No-tillage      No-tillage            NT            NT
# 7           2006     Chisel plow     Chisel plow            RT            RT
# 8           2006  Moldboard plow  Moldboard plow            CT            CT
# 9           2008      No-tillage      No-tillage            NT            NT
# 10          2008     Chisel plow     Chisel plow            RT            RT
# 11          2008  Moldboard plow  Moldboard plow            CT            CT
# 12          2010      No-tillage      No-tillage            NT            NT
# 13          2010     Chisel plow     Chisel plow            RT            RT
# 14          2010  Moldboard plow  Moldboard plow            CT            CT
# 15          2012      No-tillage      No-tillage            NT            NT
# 16          2012     Chisel plow     Chisel plow            RT            RT
# 17          2012  Moldboard plow  Moldboard plow            CT            CT
#
#    Tillage_Diff Conservation_Type  BiomassCash_C  BiomassCash_T  \
# 0            No             CC-NT            293            298
# 1            No             CC-RT            393            380
# 2            No                CC            420            403
# 3            No             CC-NT            240            253
# 4            No             CC-RT            228            233
# 5            No                CC            255            245
# 6            No             CC-NT            320            330
# 7            No             CC-RT            363            400
# 8            No                CC            388            415
# 9            No             CC-NT            310            270
# 10           No             CC-RT            390            398
# 11           No                CC            360            333
# 12           No             CC-NT            297            291
# 13           No             CC-RT            274            284
# 14           No                CC            286            290
# 15           No             CC-NT            170            166
# 16           No             CC-RT            128            124
# 17           No                CC            100             96
#
#                      1.BiomassCash_Comments  Yield_C  Yield_T
# 0   Soybean population (1000 plants per ha)   2370.0   2240.0
# 1   Soybean population (1000 plants per ha)   2070.0   1780.0
# 2   Soybean population (1000 plants per ha)   1980.0   1980.0
# 3   Soybean population (1000 plants per ha)      NaN      NaN
# 4   Soybean population (1000 plants per ha)      NaN      NaN
# 5   Soybean population (1000 plants per ha)      NaN      NaN
# 6   Soybean population (1000 plants per ha)   3170.0   2900.0
# 7   Soybean population (1000 plants per ha)   3370.0   2840.0
# 8   Soybean population (1000 plants per ha)   3100.0   3300.0
# 9   Soybean population (1000 plants per ha)   2840.0   3100.0
# 10  Soybean population (1000 plants per ha)   2840.0   2900.0
# 11  Soybean population (1000 plants per ha)   3040.0   3040.0
# 12  Soybean population (1000 plants per ha)   2940.0   2860.0
# 13  Soybean population (1000 plants per ha)   2790.0   2530.0
# 14  Soybean population (1000 plants per ha)   2880.0   2750.0
# 15  Soybean population (1000 plants per ha)   2650.0   2870.0
# 16  Soybean population (1000 plants per ha)   1960.0   2160.0
# 17  Soybean population (1000 plants per ha)   1820.0   1710.0

# %% [markdown]
# ### Grouping ###

# %%
soy2 = soy.groupby(['Conservation_Type']).groups.keys()

# %%
soy2
# Out:
# dict_keys(['CC', 'CC-NT', 'CC-RT'])

# %% [markdown]
# ### Dropping NaN values: year 2004 ###

# %%
soyC2 =soy.dropna()
soyC2
# Out:
#     SamplingYear       Tillage_C       Tillage_T Tillage_Top_C Tillage_Top_T  \
# 0           2002      No-tillage      No-tillage            NT            NT
# 1           2002     Chisel plow     Chisel plow            RT            RT
# 2           2002  Moldboard plow  Moldboard plow            CT            CT
# 6           2006      No-tillage      No-tillage            NT            NT
# 7           2006     Chisel plow     Chisel plow            RT            RT
# 8           2006  Moldboard plow  Moldboard plow            CT            CT
# 9           2008      No-tillage      No-tillage            NT            NT
# 10          2008     Chisel plow     Chisel plow            RT            RT
# 11          2008  Moldboard plow  Moldboard plow            CT            CT
# 12          2010      No-tillage      No-tillage            NT            NT
# 13          2010     Chisel plow     Chisel plow            RT            RT
# 14          2010  Moldboard plow  Moldboard plow            CT            CT
# 15          2012      No-tillage      No-tillage            NT            NT
# 16          2012     Chisel plow     Chisel plow            RT            RT
# 17          2012  Moldboard plow  Moldboard plow            CT            CT
#
#    Tillage_Diff Conservation_Type  BiomassCash_C  BiomassCash_T  \
# 0            No             CC-NT            293            298
# 1            No             CC-RT            393            380
# 2            No                CC            420            403
# 6            No             CC-NT            320            330
# 7            No             CC-RT            363            400
# 8            No                CC            388            415
# 9            No             CC-NT            310            270
# 10           No             CC-RT            390            398
# 11           No                CC            360            333
# 12           No             CC-NT            297            291
# 13           No             CC-RT            274            284
# 14           No                CC            286            290
# 15           No             CC-NT            170            166
# 16           No             CC-RT            128            124
# 17           No                CC            100             96
#
#                      1.BiomassCash_Comments  Yield_C  Yield_T
# 0   Soybean population (1000 plants per ha)   2370.0   2240.0
# 1   Soybean population (1000 plants per ha)   2070.0   1780.0
# 2   Soybean population (1000 plants per ha)   1980.0   1980.0
# 6   Soybean population (1000 plants per ha)   3170.0   2900.0
# 7   Soybean population (1000 plants per ha)   3370.0   2840.0
# 8   Soybean population (1000 plants per ha)   3100.0   3300.0
# 9   Soybean population (1000 plants per ha)   2840.0   3100.0
# 10  Soybean population (1000 plants per ha)   2840.0   2900.0
# 11  Soybean population (1000 plants per ha)   3040.0   3040.0
# 12  Soybean population (1000 plants per ha)   2940.0   2860.0
# 13  Soybean population (1000 plants per ha)   2790.0   2530.0
# 14  Soybean population (1000 plants per ha)   2880.0   2750.0
# 15  Soybean population (1000 plants per ha)   2650.0   2870.0
# 16  Soybean population (1000 plants per ha)   1960.0   2160.0
# 17  Soybean population (1000 plants per ha)   1820.0   1710.0

# %% [markdown]
# # Soybean Yield Total: CC #

# %% [markdown]
# ### Finding of Control Yield of Crops ###

# %%
soyC_CC = soyC2[soyC2['Conservation_Type']=='CC'].groupby('SamplingYear').agg(
    soyC_CC = ('Yield_C', sum),
)

soyC_CC
# Out:
#               soyC_CC
# SamplingYear
# 2002           1980.0
# 2006           3100.0
# 2008           3040.0
# 2010           2880.0
# 2012           1820.0

# %%
soyT_CC = soyC2[soyC2['Conservation_Type']=='CC'].groupby('SamplingYear').agg(
   soyT_CC = ('Yield_T', sum),
)

soyT_CC
# Out:
#               soyT_CC
# SamplingYear
# 2002           1980.0
# 2006           3300.0
# 2008           3040.0
# 2010           2750.0
# 2012           1710.0

# %% [markdown]
# ### Concatenating ###

# %%
soyCC = pd.concat([soyC_CC, soyT_CC], axis=1)

soyCC
# Out:
#               soyC_CC  soyT_CC
# SamplingYear
# 2002           1980.0   1980.0
# 2006           3100.0   3300.0
# 2008           3040.0   3040.0
# 2010           2880.0   2750.0
# 2012           1820.0   1710.0

# %% [markdown]
# # Soybean Yield Total: CC-RT #

# %%
soyC_RT = soyC2[soyC2['Conservation_Type']=='CC-RT'].groupby('SamplingYear').agg(
    soyC_RT = ('Yield_C', sum),
)

soyC_RT
# Out:
#               soyC_RT
# SamplingYear
# 2002           2070.0
# 2006           3370.0
# 2008           2840.0
# 2010           2790.0
# 2012           1960.0

# %%
soyT_RT = soyC2[soyC2['Conservation_Type']=='CC-RT'].groupby('SamplingYear').agg(
    soyT_RT = ('Yield_T', sum),
)
soyT_RT
# Out:
#               soyT_RT
# SamplingYear
# 2002           1780.0
# 2006           2840.0
# 2008           2900.0
# 2010           2530.0
# 2012           2160.0

# %% [markdown]
# ### Concatenating ###

# %%
soyRT = pd.concat([soyC_RT, soyT_RT], axis=1)

soyRT
# Out:
#               soyC_RT  soyT_RT
# SamplingYear
# 2002           2070.0   1780.0
# 2006           3370.0   2840.0
# 2008           2840.0   2900.0
# 2010           2790.0   2530.0
# 2012           1960.0   2160.0

# %% [markdown]
# # Soybean Yield Total: CC-NT #

# %%
soyC_NT = soyC2[soyC2['Conservation_Type']=='CC-NT'].groupby('SamplingYear').agg(
    soyC_NT = ('Yield_C', sum),
)

soyC_NT
# Out:
#               soyC_NT
# SamplingYear
# 2002           2370.0
# 2006           3170.0
# 2008           2840.0
# 2010           2940.0
# 2012           2650.0

# %%
soyT_NT = soyC2[soyC2['Conservation_Type']=='CC-NT'].groupby('SamplingYear').agg(
    soyT_NT = ('Yield_T', sum),
)

soyT_NT
# Out:
#               soyT_NT
# SamplingYear
# 2002           2240.0
# 2006           2900.0
# 2008           3100.0
# 2010           2860.0
# 2012           2870.0

# %%
soyNT = pd.concat([soyC_NT, soyT_NT], axis=1)

soyNT
# Out:
#               soyC_NT  soyT_NT
# SamplingYear
# 2002           2370.0   2240.0
# 2006           3170.0   2900.0
# 2008           2840.0   3100.0
# 2010           2940.0   2860.0
# 2012           2650.0   2870.0

# %%
soy_yield = pd.concat([soyCC,soyRT,soyNT], axis=1)

soy_yield
# Out:
#               soyC_CC  soyT_CC  soyC_RT  soyT_RT  soyC_NT  soyT_NT
# SamplingYear
# 2002           1980.0   1980.0   2070.0   1780.0   2370.0   2240.0
# 2006           3100.0   3300.0   3370.0   2840.0   3170.0   2900.0
# 2008           3040.0   3040.0   2840.0   2900.0   2840.0   3100.0
# 2010           2880.0   2750.0   2790.0   2530.0   2940.0   2860.0
# 2012           1820.0   1710.0   1960.0   2160.0   2650.0   2870.0

# %% [markdown]
# # Plotting #

# %%
sns.pairplot(soy_yield)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import scipy.stats as stats
from statistics import mean

# %%
Korn = pd.read_excel('/Users/ReginaJoie/Downloads/Tillage.xlsx')

Korn
# Out:
#     SamplingYear       Tillage_C       Tillage_T Tillage_Top_C Tillage_Top_T  \
# 0           2002      No-tillage      No-tillage            NT            NT
# 1           2002     Chisel plow     Chisel plow            RT            RT
# 2           2002  Moldboard plow  Moldboard plow            CT            CT
# 3           2004      No-tillage      No-tillage            NT            NT
# 4           2004     Chisel plow     Chisel plow            RT            RT
# 5           2004  Moldboard plow  Moldboard plow            CT            CT
# 6           2006      No-tillage      No-tillage            NT            NT
# 7           2006     Chisel plow     Chisel plow            RT            RT
# 8           2006  Moldboard plow  Moldboard plow            CT            CT
# 9           2008      No-tillage      No-tillage            NT            NT
# 10          2008     Chisel plow     Chisel plow            RT            RT
# 11          2008  Moldboard plow  Moldboard plow            CT            CT
# 12          2010      No-tillage      No-tillage            NT            NT
# 13          2010     Chisel plow     Chisel plow            RT            RT
# 14          2010  Moldboard plow  Moldboard plow            CT            CT
# 15          2012      No-tillage      No-tillage            NT            NT
# 16          2012     Chisel plow     Chisel plow            RT            RT
# 17          2012  Moldboard plow  Moldboard plow            CT            CT
# 18          2002      No-tillage      No-tillage            NT            NT
# 19          2002     Chisel plow     Chisel plow            RT            RT
# 20          2002  Moldboard plow  Moldboard plow            CT            CT
# 21          2004      No-tillage      No-tillage            NT            NT
# 22          2004     Chisel plow     Chisel plow            RT            RT
# 23          2004  Moldboard plow  Moldboard plow            CT            CT
# 24          2006      No-tillage      No-tillage            NT            NT
# 25          2006     Chisel plow     Chisel plow            RT            RT
# 26          2006  Moldboard plow  Moldboard plow            CT            CT
# 27          2008      No-tillage      No-tillage            NT            NT
# 28          2008     Chisel plow     Chisel plow            RT            RT
# 29          2008  Moldboard plow  Moldboard plow            CT            CT
# 30          2010      No-tillage      No-tillage            NT            NT
# 31          2010     Chisel plow     Chisel plow            RT            RT
# 32          2010  Moldboard plow  Moldboard plow            CT            CT
# 33          2012      No-tillage      No-tillage            NT            NT
# 34          2012     Chisel plow     Chisel plow            RT            RT
# 35          2012  Moldboard plow  Moldboard plow            CT            CT
#
#    Tillage_Diff Conservation_Type  BiomassCash_C  BiomassCash_T  \
# 0            No             CC-NT            293            298
# 1            No             CC-RT            393            380
# 2            No                CC            420            403
# 3            No             CC-NT            240            253
# 4            No             CC-RT            228            233
# 5            No                CC            255            245
# 6            No             CC-NT            320            330
# 7            No             CC-RT            363            400
# 8            No                CC            388            415
# 9            No             CC-NT            310            270
# 10           No             CC-RT            390            398
# 11           No                CC            360            333
# 12           No             CC-NT            297            291
# 13           No             CC-RT            274            284
# 14           No                CC            286            290
# 15           No             CC-NT            170            166
# 16           No             CC-RT            128            124
# 17           No                CC            100             96
# 18           No             CC-NT             63             65
# 19           No             CC-RT             56             58
# 20           No                CC             68             64
# 21           No             CC-NT             60             61
# 22           No             CC-RT             61             60
# 23           No                CC             60             61
# 24           No             CC-NT             71             72
# 25           No             CC-RT             76             76
# 26           No                CC             69             68
# 27           No             CC-NT             68             66
# 28           No             CC-RT             68             68
# 29           No                CC             68             66
# 30           No             CC-NT             65             69
# 31           No             CC-RT             66             66
# 32           No                CC             64             68
# 33           No             CC-NT             75             76
# 34           No             CC-RT             69             66
# 35           No                CC             62             61
#
#                      1.BiomassCash_Comments  Yield_C  Yield_T
# 0   Soybean population (1000 plants per ha)   2370.0   2240.0
# 1   Soybean population (1000 plants per ha)   2070.0   1780.0
# 2   Soybean population (1000 plants per ha)   1980.0   1980.0
# 3   Soybean population (1000 plants per ha)      NaN      NaN
# 4   Soybean population (1000 plants per ha)      NaN      NaN
# 5   Soybean population (1000 plants per ha)      NaN      NaN
# 6   Soybean population (1000 plants per ha)   3170.0   2900.0
# 7   Soybean population (1000 plants per ha)   3370.0   2840.0
# 8   Soybean population (1000 plants per ha)   3100.0   3300.0
# 9   Soybean population (1000 plants per ha)   2840.0   3100.0
# 10  Soybean population (1000 plants per ha)   2840.0   2900.0
# 11  Soybean population (1000 plants per ha)   3040.0   3040.0
# 12  Soybean population (1000 plants per ha)   2940.0   2860.0
# 13  Soybean population (1000 plants per ha)   2790.0   2530.0
# 14  Soybean population (1000 plants per ha)   2880.0   2750.0
# 15  Soybean population (1000 plants per ha)   2650.0   2870.0
# 16  Soybean population (1000 plants per ha)   1960.0   2160.0
# 17  Soybean population (1000 plants per ha)   1820.0   1710.0
# 18     Corn population (1000 plants per ha)   9930.0   9530.0
# 19     Corn population (1000 plants per ha)   9900.0   9300.0
# 20     Corn population (1000 plants per ha)  10400.0  10200.0
# 21     Corn population (1000 plants per ha)   6670.0   6860.0
# 22     Corn population (1000 plants per ha)   7330.0   7130.0
# 23     Corn population (1000 plants per ha)   7720.0   8450.0
# 24     Corn population (1000 plants per ha)  11440.0  11400.0
# 25     Corn population (1000 plants per ha)  11860.0  11630.0
# 26     Corn population (1000 plants per ha)  11420.0  12040.0
# 27     Corn population (1000 plants per ha)   6460.0   6200.0
# 28     Corn population (1000 plants per ha)   6800.0   6730.0
# 29     Corn population (1000 plants per ha)   6800.0   6730.0
# 30     Corn population (1000 plants per ha)  13130.0  12330.0
# 31     Corn population (1000 plants per ha)  13610.0  12640.0
# 32     Corn population (1000 plants per ha)  14030.0  13970.0
# 33     Corn population (1000 plants per ha)   6130.0   6100.0
# 34     Corn population (1000 plants per ha)   6850.0   7030.0
# 35     Corn population (1000 plants per ha)   7680.0   6490.0

# %% [markdown]
# ### Dropping Soybean Population and keeping Corn Population ###

# %%
corn = Korn.drop(Korn.index[:18])

corn
# Out:
#     SamplingYear       Tillage_C       Tillage_T Tillage_Top_C Tillage_Top_T  \
# 18          2002      No-tillage      No-tillage            NT            NT
# 19          2002     Chisel plow     Chisel plow            RT            RT
# 20          2002  Moldboard plow  Moldboard plow            CT            CT
# 21          2004      No-tillage      No-tillage            NT            NT
# 22          2004     Chisel plow     Chisel plow            RT            RT
# 23          2004  Moldboard plow  Moldboard plow            CT            CT
# 24          2006      No-tillage      No-tillage            NT            NT
# 25          2006     Chisel plow     Chisel plow            RT            RT
# 26          2006  Moldboard plow  Moldboard plow            CT            CT
# 27          2008      No-tillage      No-tillage            NT            NT
# 28          2008     Chisel plow     Chisel plow            RT            RT
# 29          2008  Moldboard plow  Moldboard plow            CT            CT
# 30          2010      No-tillage      No-tillage            NT            NT
# 31          2010     Chisel plow     Chisel plow            RT            RT
# 32          2010  Moldboard plow  Moldboard plow            CT            CT
# 33          2012      No-tillage      No-tillage            NT            NT
# 34          2012     Chisel plow     Chisel plow            RT            RT
# 35          2012  Moldboard plow  Moldboard plow            CT            CT
#
#    Tillage_Diff Conservation_Type  BiomassCash_C  BiomassCash_T  \
# 18           No             CC-NT             63             65
# 19           No             CC-RT             56             58
# 20           No                CC             68             64
# 21           No             CC-NT             60             61
# 22           No             CC-RT             61             60
# 23           No                CC             60             61
# 24           No             CC-NT             71             72
# 25           No             CC-RT             76             76
# 26           No                CC             69             68
# 27           No             CC-NT             68             66
# 28           No             CC-RT             68             68
# 29           No                CC             68             66
# 30           No             CC-NT             65             69
# 31           No             CC-RT             66             66
# 32           No                CC             64             68
# 33           No             CC-NT             75             76
# 34           No             CC-RT             69             66
# 35           No                CC             62             61
#
#                   1.BiomassCash_Comments  Yield_C  Yield_T
# 18  Corn population (1000 plants per ha)   9930.0   9530.0
# 19  Corn population (1000 plants per ha)   9900.0   9300.0
# 20  Corn population (1000 plants per ha)  10400.0  10200.0
# 21  Corn population (1000 plants per ha)   6670.0   6860.0
# 22  Corn population (1000 plants per ha)   7330.0   7130.0
# 23  Corn population (1000 plants per ha)   7720.0   8450.0
# 24  Corn population (1000 plants per ha)  11440.0  11400.0
# 25  Corn population (1000 plants per ha)  11860.0  11630.0
# 26  Corn population (1000 plants per ha)  11420.0  12040.0
# 27  Corn population (1000 plants per ha)   6460.0   6200.0
# 28  Corn population (1000 plants per ha)   6800.0   6730.0
# 29  Corn population (1000 plants per ha)   6800.0   6730.0
# 30  Corn population (1000 plants per ha)  13130.0  12330.0
# 31  Corn population (1000 plants per ha)  13610.0  12640.0
# 32  Corn population (1000 plants per ha)  14030.0  13970.0
# 33  Corn population (1000 plants per ha)   6130.0   6100.0
# 34  Corn population (1000 plants per ha)   6850.0   7030.0
# 35  Corn population (1000 plants per ha)   7680.0   6490.0

# %% [markdown]
# # Corn Yield Total: CC #

# %%
cornC_CC = corn[corn['Conservation_Type']=='CC'].groupby('SamplingYear').agg(
    cornC_CC = ('Yield_C', sum),
)

cornC_CC
# Out:
#               cornC_CC
# SamplingYear
# 2002           10400.0
# 2004            7720.0
# 2006           11420.0
# 2008            6800.0
# 2010           14030.0
# 2012            7680.0

# %%
cornT_CC = corn[corn['Conservation_Type']=='CC'].groupby('SamplingYear').agg(
    cornT_CC = ('Yield_T', sum),
)

cornT_CC
# Out:
#               cornT_CC
# SamplingYear
# 2002           10200.0
# 2004            8450.0
# 2006           12040.0
# 2008            6730.0
# 2010           13970.0
# 2012            6490.0

# %%
# Concatenate #

# %%
cornCC = pd.concat([cornC_CC, cornT_CC], axis=1)

cornCC
# Out:
#               cornC_CC  cornT_CC
# SamplingYear
# 2002           10400.0   10200.0
# 2004            7720.0    8450.0
# 2006           11420.0   12040.0
# 2008            6800.0    6730.0
# 2010           14030.0   13970.0
# 2012            7680.0    6490.0

# %% [markdown]
# # Corn Yield Total: CC-RT #

# %%
cornC_RT = corn[corn['Conservation_Type']=='CC-RT'].groupby('SamplingYear').agg(
    cornC_RT = ('Yield_C', sum),
)

cornC_RT
# Out:
#               cornC_RT
# SamplingYear
# 2002            9900.0
# 2004            7330.0
# 2006           11860.0
# 2008            6800.0
# 2010           13610.0
# 2012            6850.0

# %%
cornT_RT = corn[corn['Conservation_Type']=='CC-RT'].groupby('SamplingYear').agg(
    cornT_RT = ('Yield_T', sum),
)

cornT_RT
# Out:
#               cornT_RT
# SamplingYear
# 2002            9300.0
# 2004            7130.0
# 2006           11630.0
# 2008            6730.0
# 2010           12640.0
# 2012            7030.0

# %%
cornRT = pd.concat([cornC_RT, cornT_RT], axis=1)

cornRT
# Out:
#               cornC_RT  cornT_RT
# SamplingYear
# 2002            9900.0    9300.0
# 2004            7330.0    7130.0
# 2006           11860.0   11630.0
# 2008            6800.0    6730.0
# 2010           13610.0   12640.0
# 2012            6850.0    7030.0

# %% [markdown]
# # Corn Yield Total: CC-NT #

# %%
cornC_NT = corn[corn['Conservation_Type']=='CC-NT'].groupby('SamplingYear').agg(
    cornC_NT = ('Yield_C', sum),
)

cornC_NT
# Out:
#               cornC_NT
# SamplingYear
# 2002            9930.0
# 2004            6670.0
# 2006           11440.0
# 2008            6460.0
# 2010           13130.0
# 2012            6130.0

# %%
cornT_NT = corn[corn['Conservation_Type']=='CC-NT'].groupby('SamplingYear').agg(
    cornT_NT = ('Yield_T', sum),
)

cornT_NT
# Out:
#               cornT_NT
# SamplingYear
# 2002            9530.0
# 2004            6860.0
# 2006           11400.0
# 2008            6200.0
# 2010           12330.0
# 2012            6100.0

# %%
cornNT = pd.concat([cornC_NT, cornT_NT], axis=1)

cornNT
# Out:
#               cornC_NT  cornT_NT
# SamplingYear
# 2002            9930.0    9530.0
# 2004            6670.0    6860.0
# 2006           11440.0   11400.0
# 2008            6460.0    6200.0
# 2010           13130.0   12330.0
# 2012            6130.0    6100.0

# %%
corn_yield = pd.concat([cornCC,cornRT,cornNT], axis=1)

corn_yield
# Out:
#               cornC_CC  cornT_CC  cornC_RT  cornT_RT  cornC_NT  cornT_NT
# SamplingYear
# 2002           10400.0   10200.0    9900.0    9300.0    9930.0    9530.0
# 2004            7720.0    8450.0    7330.0    7130.0    6670.0    6860.0
# 2006           11420.0   12040.0   11860.0   11630.0   11440.0   11400.0
# 2008            6800.0    6730.0    6800.0    6730.0    6460.0    6200.0
# 2010           14030.0   13970.0   13610.0   12640.0   13130.0   12330.0
# 2012            7680.0    6490.0    6850.0    7030.0    6130.0    6100.0

# %%
sns.pairplot(corn_yield)

# %%
SoyCornYield = pd.concat([soy_yield, corn_yield], axis=1)

SoyCornYield
# Out:
#               soyC_CC  soyT_CC  soyC_RT  soyT_RT  soyC_NT  soyT_NT  cornC_CC  \
# SamplingYear
# 2002           1980.0   1980.0   2070.0   1780.0   2370.0   2240.0   10400.0
# 2006           3100.0   3300.0   3370.0   2840.0   3170.0   2900.0   11420.0
# 2008           3040.0   3040.0   2840.0   2900.0   2840.0   3100.0    6800.0
# 2010           2880.0   2750.0   2790.0   2530.0   2940.0   2860.0   14030.0
# 2012           1820.0   1710.0   1960.0   2160.0   2650.0   2870.0    7680.0
# 2004              NaN      NaN      NaN      NaN      NaN      NaN    7720.0
#
#               cornT_CC  cornC_RT  cornT_RT  cornC_NT  cornT_NT
# SamplingYear
# 2002           10200.0    9900.0    9300.0    9930.0    9530.0
# 2006           12040.0   11860.0   11630.0   11440.0   11400.0
# 2008            6730.0    6800.0    6730.0    6460.0    6200.0
# 2010           13970.0   13610.0   12640.0   13130.0   12330.0
# 2012            6490.0    6850.0    7030.0    6130.0    6100.0
# 2004            8450.0    7330.0    7130.0    6670.0    6860.0

# %%
sns.pairplot(SoyCornYield)

# %% [markdown]
# ## Histogram

# %%
sns.catplot(x="SamplingYear", y="Yield_C", hue="Conservation_Type", kind="bar", data=corn)

# %%
sns.catplot(x="SamplingYear", y="Yield_T", hue="Conservation_Type", kind="bar", data=corn)

# %%
sns.catplot(x="SamplingYear", y="Yield_C", hue="Conservation_Type", kind="bar", data=soy)

# %%
sns.catplot(x="SamplingYear", y="Yield_T", hue="Conservation_Type", kind="bar", data=soy)

# %%
sns.catplot(x="SamplingYear", y="BiomassCash_C", hue="1.BiomassCash_Comments", kind="bar", data=corn)

# %%
sns.catplot(x="SamplingYear", y="BiomassCash_C", hue="1.BiomassCash_Comments", kind="bar", data=soy)

# %%
ax = sns.heatmap(SoyCornYield, xticklabels=2, yticklabels=False)

# %%
sns.catplot(x="SamplingYear", y="Yield_C", hue="Conservation_Type", kind="bar", data=soy)

# %%
sns.pairplot(corn, hue = "SamplingYear")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(soy, hue = "Conservation_Type", markers = ["o", "s", "D"])

# %%
sns.pairplot(soy, hue = "SamplingYear")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(corn, 
             vars = ['Yield_C', 'SamplingYear',], 
             hue = 'Conservation_Type', diag_kind = 'kde',
             plot_kws = {'alpha': .6, 's': 50, 'edgecolor': 'black'},
             size = 5);
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x=corn['Conservation_Type'], y=corn['Yield_C']);

# %%
sns.boxplot(x=corn['Conservation_Type'], y=corn['Yield_T']);

# %%
sns.jointplot(SoyCornYield)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-906e0c1272b1> in <module>
# ----> 1 sns.jointplot(SoyCornYield)
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2119
#    2120     # Initialize the JointGrid object
# -> 2121     grid = JointGrid(
#    2122         data=data, x=x, y=y, hue=hue,
#    2123         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size, marginal_ticks, hue, palette, hue_order, hue_norm)
#    1628
#    1629         # Process the input variables
# -> 1630         p = VectorPlotter(data=data, variables=dict(x=x, y=y, hue=hue))
#    1631         plot_data = p.plot_data.loc[:, p.plot_data.notna().any()]
#    1632
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     924         # Construct a tidy plot DataFrame. This will convert a number of
#     925         # types automatically, aligning on index in case of pandas objects
# --> 926         plot_data = pd.DataFrame(plot_data)
#     927
#     928         # Reduce the variables dictionary to fields with valid data
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# --> 502     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     503
#     504
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     118         # figure out the index, if necessary
#     119         if index is None:
# --> 120             index = _extract_index(arrays)
#     121         else:
#     122             index = ensure_index(index)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     662
#     663         if not indexes and not raw_lengths:
# --> 664             raise ValueError("If using all scalar values, you must pass an index")
#     665
#     666         elif have_series:
#
# ValueError: If using all scalar values, you must pass an index
